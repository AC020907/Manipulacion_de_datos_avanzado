# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Comentario general del revisor</b> <a class="tocSkip"></a><br />
# Status del proyecto: <b>Aprobado</b>
# </div>

# %% [markdown]
# ¡Hola!<br />
# Soy **Francisco Cortés**, estoy contento de revisar tu proyecto y ser parte de tu proceso de aprendizaje.
# A lo largo del texto, haré algunas observaciones sobre mejoras en el código y también haré comentarios sobre tus percepciones sobre el tema. Si existe algún error en el código, no te preocupes, estoy aquí para ayudarte a mejorarlo, en la primera iteración te lo señalaré para que tengas la oportunidad de corregirlo, pero si aún no encuentras una solución para esta tarea, te daré una pista más precisa en la próxima iteración y también algunos ejemplos prácticos. Estaré abierto a retroalimentación y discusiones sobre el tema.<br />
# Encontrarás mis comentarios a continuación - **por favor no los muevas, modifiques o borres**.
# Revisaré cuidadosamente tu código para comprobar que se han cumplido con los requisitos y te proporcionaré mis comentarios en cajas verdes, amarillas o rojas como esta:
#
# <div class="alert alert-block alert-success">
# <b>Comentario del revisor</b> <a class="tocSkip"></a>
#
# Si la ejecución fue perfecta succesfully.
# </div>
#
# <div class="alert alert-block alert-warning">
# <b>Comentario del revisor</b> <a class="tocSkip"></a>
#
# Si existe alguna recomendación para que tu código mejore.
# </div>
#
# <div class="alert alert-block alert-danger">
#
# <b>Comentario del revisor</b> <a class="tocSkip"></a>
#
# Si existen correcciones necesarias para cumplir con los requisitos. El trabajo no puede ser aceptado si hay alguna caja roja.
# </div>
#
# Puedes responderme de la siguiente manera:
#
# <div class="alert alert-block alert-info">
# <b>Respuesta del estudiante.</b> <a class="tocSkip"></a>
# </div>

# %% [markdown]
# <div style="border:solid green 2px; padding: 20px">
#
# 👋 **¡Hola! Soy Dot, tu revisor de IA.**
#
# He completado la primera revisión de tu código. A continuación, encontrarás mis comentarios y sugerencias de mejora.
#
# **¿Qué debes hacer ahora?**
#
# 1. **Revisar:** Lee mis comentarios en el notebook más abajo.
# 2. **Decidir:**
# * **¿Estás de acuerdo con el feedback?** ¡Genial! Actualiza tu código según las sugerencias.
# * **¿No estás de acuerdo o crees que es un error?** ¡No hay problema! Puedes dejar tu código exactamente como está.
#
#
# 3. **Volver a enviar:** Envía tu proyecto de nuevo. **Tu próxima iteración será revisada por un experto humano**, independientemente de si hiciste cambios o no.
#
# -------------------------------------------------------------------------------------------------------------
# Mis comentarios están más abajo. **Te pido amablemente que no los muevas, modifiques ni elimines**.
#
# Verás mis comentarios resaltados en cuadros verdes, amarillos o rojos como estos:
#
# <div class="alert alert-block alert-success">
# <b>Reviewer's comment, Iteration X</b> <a class="tocSkip"></a>
#
# Correcto. Todo se ha hecho exitosamente.
# </div>
#
# <div class="alert alert-block alert-warning">
# <b>Reviewer's comment, Iteration X</b> <a class="tocSkip"></a>
#
# Observaciones. Algunas recomendaciones.
# </div>
#
# <div class="alert alert-block alert-danger">
# <b>Reviewer's comment, Iteration X</b> <a class="tocSkip"></a>
#
# Necesita corrección. El bloque requiere algunas correcciones.
# </div>

# %% [markdown]
# # ¡Llena ese carrito!

# %% [markdown]
# # Introducción
#
# Instacart es una plataforma de entregas de comestibles donde la clientela puede registrar un pedido y hacer que se lo entreguen, similar a Uber Eats y Door Dash.
# El conjunto de datos que te hemos proporcionado tiene modificaciones del original. Redujimos el tamaño del conjunto para que tus cálculos se hicieran más rápido e introdujimos valores ausentes y duplicados. Tuvimos cuidado de conservar las distribuciones de los datos originales cuando hicimos los cambios.
#
# Debes completar tres pasos. Para cada uno de ellos, escribe una breve introducción que refleje con claridad cómo pretendes resolver cada paso, y escribe párrafos explicatorios que justifiquen tus decisiones al tiempo que avanzas en tu solución.  También escribe una conclusión que resuma tus hallazgos y elecciones.

# %% [markdown]
# ## Diccionario de datos
#
# Hay cinco tablas en el conjunto de datos, y tendrás que usarlas todas para hacer el preprocesamiento de datos y el análisis exploratorio de datos. A continuación se muestra un diccionario de datos que enumera las columnas de cada tabla y describe los datos que contienen.
#
# - `instacart_orders.csv`: cada fila corresponde a un pedido en la aplicación Instacart.
#     - `'order_id'`: número de ID que identifica de manera única cada pedido.
#     - `'user_id'`: número de ID que identifica de manera única la cuenta de cada cliente.
#     - `'order_number'`: el número de veces que este cliente ha hecho un pedido.
#     - `'order_dow'`: día de la semana en que se hizo el pedido (0 si es domingo).
#     - `'order_hour_of_day'`: hora del día en que se hizo el pedido.
#     - `'days_since_prior_order'`: número de días transcurridos desde que este cliente hizo su pedido anterior.
# - `products.csv`: cada fila corresponde a un producto único que pueden comprar los clientes.
#     - `'product_id'`: número ID que identifica de manera única cada producto.
#     - `'product_name'`: nombre del producto.
#     - `'aisle_id'`: número ID que identifica de manera única cada categoría de pasillo de víveres.
#     - `'department_id'`: número ID que identifica de manera única cada departamento de víveres.
# - `order_products.csv`: cada fila corresponde a un artículo pedido en un pedido.
#     - `'order_id'`: número de ID que identifica de manera única cada pedido.
#     - `'product_id'`: número ID que identifica de manera única cada producto.
#     - `'add_to_cart_order'`: el orden secuencial en el que se añadió cada artículo en el carrito.
#     - `'reordered'`: 0 si el cliente nunca ha pedido este producto antes, 1 si lo ha pedido.
# - `aisles.csv`
#     - `'aisle_id'`: número ID que identifica de manera única cada categoría de pasillo de víveres.
#     - `'aisle'`: nombre del pasillo.
# - `departments.csv`
#     - `'department_id'`: número ID que identifica de manera única cada departamento de víveres.
#     - `'department'`: nombre del departamento.

# %% [markdown]
# # Paso 1. Descripción de los datos
#
# Lee los archivos de datos (`/datasets/instacart_orders.csv`, `/datasets/products.csv`, `/datasets/aisles.csv`, `/datasets/departments.csv` y `/datasets/order_products.csv`) con `pd.read_csv()` usando los parámetros adecuados para leer los datos correctamente. Verifica la información para cada DataFrame creado.

# %% [markdown]
# ## Plan de solución
#
# Escribe aquí tu plan de solución para el Paso 1. Descripción de los datos.
#
# Para poder empezar con el proyecto, se hace necesario seguir una serie de pasos los cuales son los siguietnes:
#
# #1.Importar librerias necesarias.
#
# #2.Leer los archivos de los datos de forma correcta.
#
# #3.Utilizar el metodo .info() en cada uno de los DataFrame para tener claridad y hacernos una idea de los posibles errores de cada uno como lo serian datos duplicados y/o nulos y la informacion que contiene cada DataFrame, ademas de el tipo de datos.
#
# #4.Utilizar el metodo head para tener una idea de somera de como estan organizados los datos.
#
# #5.Identificar con toda esta informacion las columnas clave de cada DataFrame.

# %%
# importar librerías
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
# leer conjuntos de datos en los DataFrames
orders=pd.read_csv('/datasets/instacart_orders.csv',sep=';')
products=pd.read_csv('/datasets/products.csv',sep=';')
aisles=pd.read_csv('/datasets/aisles.csv',sep=';')
departments=pd.read_csv('/datasets/departments.csv',sep=';')
order_products=pd.read_csv('/datasets/order_products.csv',sep=';')

# %%
# mostrar información del DataFrame
orders.info()
print(orders.head())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 478967 entries, 0 to 478966
# Data columns (total 6 columns):
#  #   Column                  Non-Null Count   Dtype
# ---  ------                  --------------   -----
#  0   order_id                478967 non-null  int64
#  1   user_id                 478967 non-null  int64
#  2   order_number            478967 non-null  int64
#  3   order_dow               478967 non-null  int64
#  4   order_hour_of_day       478967 non-null  int64
#  5   days_since_prior_order  450148 non-null  float64
# dtypes: float64(1), int64(5)
# memory usage: 21.9 MB
#    order_id  user_id  order_number  order_dow  order_hour_of_day  \
# 0   1515936   183418            11          6                 13
# 1   1690866   163593             5          5                 12
# 2   1454967    39980             4          5                 19
# 3   1768857    82516            56          0                 20
# ...

# %%
# mostrar información del DataFrame
products.info()
print(products.head())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 49694 entries, 0 to 49693
# Data columns (total 4 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   product_id     49694 non-null  int64
#  1   product_name   48436 non-null  object
#  2   aisle_id       49694 non-null  int64
#  3   department_id  49694 non-null  int64
# dtypes: int64(3), object(1)
# memory usage: 1.5+ MB
#    product_id                                       product_name  aisle_id  \
# 0           1                         Chocolate Sandwich Cookies        61
# 1           2                                   All-Seasons Salt       104
# 2           3               Robust Golden Unsweetened Oolong Tea        94
# 3           4  Smart Ones Classic Favorites Mini Rigatoni Wit...        38
# 4           5                          Green Chile Anytime Sauce         5
#
#    department_id
# 0             19
# 1             13
# 2              7
# 3              1
# ...

# %%
# mostrar información del DataFrame
aisles.info()
print(aisles.head())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 134 entries, 0 to 133
# Data columns (total 2 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   aisle_id  134 non-null    int64
#  1   aisle     134 non-null    object
# dtypes: int64(1), object(1)
# memory usage: 2.2+ KB
#    aisle_id                       aisle
# 0         1       prepared soups salads
# 1         2           specialty cheeses
# 2         3         energy granola bars
# 3         4               instant foods
# 4         5  marinades meat preparation

# %%
# mostrar información del DataFrame
departments.info()
print(departments.head())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21 entries, 0 to 20
# Data columns (total 2 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   department_id  21 non-null     int64
#  1   department     21 non-null     object
# dtypes: int64(1), object(1)
# memory usage: 464.0+ bytes
#    department_id department
# 0              1     frozen
# 1              2      other
# 2              3     bakery
# 3              4    produce
# 4              5    alcohol

# %%
# mostrar información del DataFrame
order_products.info()
print(order_products.head())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4545007 entries, 0 to 4545006
# Data columns (total 4 columns):
#  #   Column             Dtype
# ---  ------             -----
#  0   order_id           int64
#  1   product_id         int64
#  2   add_to_cart_order  float64
#  3   reordered          int64
# dtypes: float64(1), int64(3)
# memory usage: 138.7 MB
#    order_id  product_id  add_to_cart_order  reordered
# 0   2141543       11440               17.0          0
# 1    567889        1560                1.0          1
# 2   2261212       26683                1.0          1
# 3    491251        8670               35.0          1
# 4   2571142        1940                5.0          1

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Comentario del revisor</b> <a class="tocSkip"></a><br />
# Correcto!<br/>
# Buena manera de leer los datos y buenas observaciones iniciales.<br/>
#
# La razón del porque no te aparecen todos los valores del dataframe `order_products` es porque es contiene mucha información y pandas trata de optimizar esto al no mostrar los resultados, pero le podemos indicar que lo haga de cualquier manera utilizando el siguiente argumento:
#
# ```
# order_products.info(show_counts=True)
# ```
# </div>

# %% [markdown]
# ## Conclusiones
#
# Escribe aquí tus conclusiones intermedias sobre el Paso 1.
#
# ## Descripción de los datos.
# Se logra observar que todos los datos son de tipos diferentes acorde a lo que representa cada uno. Los DataFrame cuentan con un distinto número de columnas, cada DataFrame representando la información completa de una característica específica.
#
# ## Columnas compartidas entre DataFrames:
#
# #product_id: presente en products, order_products
#
# #aisle_id: presente en products, aisles
#
# #department_id: presente en products, departments
#
# #order_id: presente en orders, order_products
#
# ## Error de tipo de datos identificado:
#
# Se detectó un error en el tipo de datos de la columna add_to_cart_order en el DataFrame order_products, la cual se encuentra almacenada como float64 cuando debería ser de tipo int (entero), ya que representa el orden secuencial en que se añadieron los artículos al carrito, valores que por naturaleza son números enteros.
#
# ## Relaciones entre DataFrames:
# #orders y order_products: Conectados por order_id
#
# #products y order_products: Conectados por product_id
#
# #products y aisles: Conectados por aisle_id
#
# #products y departments: Conectados por department_id
# Estas relaciones permiten realizar análisis completos combinando información de pedidos, productos, pasillos y departamentos para obtener informacion importante sobre los hábitos de compra de los clientes de Instacart.

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Reviewer's comment, Iteration 1</b> <a class="tocSkip"></a>
#
# El Paso 1 se completó con éxito: cargaste los cinco datasets con el separador adecuado, inspeccionaste cada DataFrame con `info()` (y una vista previa), y tus conclusiones provisionales identifican correctamente las columnas clave compartidas y un problema de tipo de dato que se abordará más adelante.
#
# </div>

# %% [markdown]
# # Paso 2. Preprocesamiento de los datos
#
# Preprocesa los datos de la siguiente manera:
#
# - Verifica y corrige los tipos de datos (por ejemplo, asegúrate de que las columnas de ID sean números enteros).
# - Identifica y completa los valores ausentes.
# - Identifica y elimina los valores duplicados.
#
# Asegúrate de explicar qué tipos de valores ausentes y duplicados encontraste, cómo los completaste o eliminaste y por qué usaste esos métodos. ¿Por qué crees que estos valores ausentes y duplicados pueden haber estado presentes en el conjunto de datos?`

# %% [markdown]
# ## Plan de solución
#
# Escribe aquí tu plan para el Paso 2. Preprocesamiento de los datos.
#
# Para llevar a cabo el procesamiento de los datos se llevaran a cabo la siguiente serie de pasos:
#
# #1. Basado en la informacion y conclusiones del paso 1 se procedera a atacar los posibles errores encontrados en cada una de las columnas de los DataFrame.
#
# #2. Corregir los tipos de datos incorrectos encontrados en el Paso 1.
#
# #3. Despues de corregidos esos primeros errores encontrados se procedera a un analisis a profundidad en cada DataFrame para encontrar los duplicados tanto explicitos como implicitos.
#
# #4. Posterior a ello se corregiran los duplicados encontrados eliminandolos para poder obtener una base de datos limpia.
#
# #5. Se buscaran posibles datos nulos en todas las columnas de los DataFrame.
#
# #6. Luego se realizara un analisis de los datos ausentes presentes en los DataFrame para determinar su causa.
#
# #7. Se realizara el reemplazo en los datos ausentes con el valor correspondiente dado por el analisis previo.
#
# #8. Base de datos limpia y lista para el analisis.

# %% [markdown]
# ## Encuentra y elimina los valores duplicados (y describe cómo tomaste tus decisiones).

# %% [markdown]
# ### `orders` data frame

# %%
# Revisa si hay pedidos duplicados
print(orders.duplicated().sum())
orders[orders.duplicated()]
# Out:
# 15
#         order_id  user_id  order_number  order_dow  order_hour_of_day  \
# 145574    794638    50898            24          3                  2
# 223105   2160484   107525            16          3                  2
# 230807   1918001   188546            14          3                  2
# 266232   1782114   106752             1          3                  2
# 273805   1112182   202304            84          3                  2
# 284038   2845099    31189            11          3                  2
# 311713   1021560    53767             3          3                  2
# 321100    408114    68324             4          3                  2
# 323900   1919531   191501            32          3                  2
# 345917   2232988    82565             1          3                  2
# 371905    391768    57671            19          3                  2
# 394347    467134    63189            21          3                  2
# ...

# %% [markdown]
# ¿Tienes líneas duplicadas? Si sí, ¿qué tienen en común?
#
# Se encontraron 15 filas completamente duplicadas en el DataFrame orders. Estas filas son duplicados exactos, es decir, comparten todos los valores en todas las columnas: order_id, user_id, order_number, order_dow, order_hour_of_day y days_since_prior_order. Esto significa que representan registros idénticos que fueron ingresados múltiples veces en el sistema, posiblemente debido a errores en el proceso de carga de datos.

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <b>Reviewer's comment, Iteration 1</b> <a class="tocSkip"></a>
#
# Las filas duplicadas marcadas en `orders` son duplicados de la fila completa (incluyendo el mismo `order_id`, `user_id`, etc.). Eso significa que *sí* son duplicados reales, así que por favor revisa tu explicación de qué tienen en común y por qué aparecen.
#
# </div>

# %%
# Basándote en tus hallazgos,
# Verifica todos los pedidos que se hicieron el miércoles a las 2:00 a.m.
print(orders[(orders['order_dow']==3) & (orders['order_hour_of_day']==2)])
# Out:
#         order_id  user_id  order_number  order_dow  order_hour_of_day  \
# 4838     2766110   162084            41          3                  2
# 5156     2190225   138285            18          3                  2
# 15506     553049    58599            13          3                  2
# 18420     382357   120200            19          3                  2
# 24691     690242    77357             2          3                  2
# ...          ...      ...           ...        ...                ...
# 457013   3384021    14881             6          3                  2
# 458816    910166   164782            18          3                  2
# 459635   1680532   106435             6          3                  2
# 468324    222962    54979            59          3                  2
# 477526   2592344    46860            38          3                  2
#
#         days_since_prior_order
# 4838                      16.0
# 5156                      11.0
# ...

# %% [markdown]
# ¿Qué sugiere este resultado?
#
# Al verificar todos los pedidos realizados los miércoles a las 2:00 a.m., se confirma que existen múltiples pedidos legítimos en ese horario con diferentes order_id y user_id. Sin embargo, los 15 duplicados identificados anteriormente son copias exactas de registros completos, no simplemente pedidos que coinciden en horario. Estos duplicados representan errores de duplicación de datos que deben ser eliminados.

# %%
# Elimina los pedidos duplicados
orders.drop_duplicates(inplace=True)

# %%
# Vuelve a verificar si hay filas duplicadas
print(orders.duplicated().sum())
orders[orders.duplicated()]
# Out:
# 0
# Empty DataFrame
# Columns: [order_id, user_id, order_number, order_dow, order_hour_of_day, days_since_prior_order]
# Index: []

# %%
# Vuelve a verificar únicamente si hay IDs duplicados de pedidos
orders[orders['order_id'].duplicated()]
# Out:
# Empty DataFrame
# Columns: [order_id, user_id, order_number, order_dow, order_hour_of_day, days_since_prior_order]
# Index: []

# %% [markdown]
# Describe brevemente tus hallazgos y lo que hiciste con ellos
#
# Se encontraron 15 filas completamente duplicadas en el DataFrame orders. Estas representan registros idénticos duplicados en el sistema, con los mismos valores en todas las columnas (order_id, user_id, order_number, etc.). Estos duplicados fueron eliminados correctamente usando drop_duplicates() ya que representan errores de duplicación de datos que comprometen la integridad del análisis.

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Comentario del revisor</b> <a class="tocSkip"></a><br />
# Bien hecho!<br/>
# Los duplicados fueron eliminados correctamente
# </div>

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <b>Reviewer's comment, Iteration 1</b> <a class="tocSkip"></a>
#
# Problema recurrente (ver nota anterior sobre duplicados en `orders`): tu resumen escrito todavía describe estos como “órdenes diferentes”, pero la verificación de duplicados indica duplicados exactos de filas. Por favor, alinea la narrativa con la definición/resultados reales de duplicados y con tu paso de eliminación.
#
# </div>

# %% [markdown]
# ### `products` data frame

# %%
# Verifica si hay filas totalmente duplicadas
products[products.duplicated()]
# Out:
# Empty DataFrame
# Columns: [product_id, product_name, aisle_id, department_id]
# Index: []

# %%
# Revisa únicamente si hay ID de productos duplicados
products[products['product_id'].duplicated()]
# Out:
# Empty DataFrame
# Columns: [product_id, product_name, aisle_id, department_id]
# Index: []

# %%
# Revisa únicamente si hay nombres duplicados de productos (convierte los nombres a letras mayúsculas para compararlos mejor)
products[products['product_name'].str.upper().duplicated()]
# Out:
#        product_id                                     product_name  aisle_id  \
# 71             72                                              NaN       100
# 109           110                                              NaN       100
# 296           297                                              NaN       100
# 416           417                                              NaN       100
# 436           437                                              NaN       100
# ...           ...                                              ...       ...
# 49689       49690                    HIGH PERFORMANCE ENERGY DRINK        64
# 49690       49691                    ORIGINAL PANCAKE & WAFFLE MIX       130
# 49691       49692  ORGANIC INSTANT OATMEAL LIGHT MAPLE BROWN SUGAR       130
# 49692       49693                           SPRING WATER BODY WASH       127
# 49693       49694                          BURRITO- STEAK & CHEESE        38
#
#        department_id
# 71                21
# ...

# %%
# Revisa si hay nombres duplicados de productos no faltantes


s=products[products['product_name'].notnull()]
print(s[s['product_name'].str.upper().duplicated()])
# Out:
#        product_id                                     product_name  aisle_id  \
# 2058         2059                                  Biotin 1000 Mcg        47
# 5455         5456                 Green Tea With Ginseng and Honey        96
# 5558         5559                           Cream Of Mushroom Soup        69
# 7558         7559                        Cinnamon Rolls with Icing       105
# 9037         9038                           American Cheese slices        21
# ...           ...                                              ...       ...
# 49689       49690                    HIGH PERFORMANCE ENERGY DRINK        64
# 49690       49691                    ORIGINAL PANCAKE & WAFFLE MIX       130
# 49691       49692  ORGANIC INSTANT OATMEAL LIGHT MAPLE BROWN SUGAR       130
# 49692       49693                           SPRING WATER BODY WASH       127
# 49693       49694                          BURRITO- STEAK & CHEESE        38
#
#        department_id
# 2058              11
# ...

# %% [markdown]
# Describe brevemente tus hallazgos y lo que hiciste con ellos.
#
# El análisis de la columna product_name evidenció la presencia de 104 valores duplicados no ausentes; sin embargo, la verificación de la clave primaria confirmó la ausencia total de duplicados en product_id, lo que garantiza que cada registro corresponde a un producto único dentro del sistema de Instacart. Esta validación permitió descartar errores estructurales en el dataset y confirmó la integridad del identificador principal utilizado para el análisis.
#
# Un examen más detallado de estos casos mostró que los nombres duplicados corresponden a productos legítimamente distintos que comparten la misma denominación, pero difieren en atributos clave como el aisle_id y, en algunos casos, el department_id. Estas diferencias reflejan variaciones en presentación, tamaño, marca o categoría del producto. En consecuencia, la eliminación de estos registros habría generado una pérdida de información relevante y una distorsión del catálogo real. La ausencia de duplicados en la clave primaria respalda la decisión de conservar todos los registros, asegurando una representación fiel de la diversidad de productos disponibles en la plataforma.

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Comentario del revisor</b> <a class="tocSkip"></a><br />
# Bien hecho!<br/>
# Los datos han sido revisados apropiadamente
# </div>

# %% [markdown]
# <div class="alert alert-block alert-warning">
# <b>Reviewer's comment, Iteration 1</b> <a class="tocSkip"></a>
#
# Identificaste valores duplicados de `product_name`, pero la tarea también te pide que indiques qué hiciste con ellos. Por favor, haz explícita la decisión y vincúlala con las comprobaciones que realizaste (p. ej., aclara que estás manteniendo intencionalmente los duplicados de nombre porque pueden representar productos/empaques distintos, y verifica que no sean duplicados en una clave más sólida como `product_id`).
#
# </div>

# %% [markdown]
# ### `departments` data frame

# %%
# Revisa si hay filas totalmente duplicadas
departments[departments.duplicated()]
# Out:
# Empty DataFrame
# Columns: [department_id, department]
# Index: []

# %%
# Revisa únicamente si hay IDs duplicadas de departamentos
departments[departments['department_id'].duplicated()]
# Out:
# Empty DataFrame
# Columns: [department_id, department]
# Index: []

# %% [markdown]
# Describe brevemente tus hallazgos y lo que hiciste con ellos.
#
# No se encontraron filas totalemtne duplicadas ni IDs duplicadas de departamentos.

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Reviewer's comment, Iteration 1</b> <a class="tocSkip"></a>
#
# Buen trabajo al comprobar tanto las filas completamente duplicadas como los IDs de departamento duplicados, y al indicar claramente el resultado. Esto es exactamente el tipo de verificación de duplicados (duplicate-checking) específica que busca el paso de preprocesamiento.
#
# </div>

# %% [markdown]
# ### `aisles` data frame

# %%
# Revisa si hay filas totalmente duplicadas
aisles[aisles.duplicated()]
# Out:
# Empty DataFrame
# Columns: [aisle_id, aisle]
# Index: []

# %%
# Revisa únicamente si hay IDs duplicadas de pasillos
aisles[aisles['aisle_id'].duplicated()]
# Out:
# Empty DataFrame
# Columns: [aisle_id, aisle]
# Index: []

# %% [markdown]
# Describe brevemente tus hallazgos y lo que hiciste con ellos.
#
# En el DataFrame de aisles no se encontraron filas totalmente duplicadas ni IDs duplicadas de los pasillos.

# %% [markdown]
# ### `order_products` data frame

# %%
# Revisa si hay filas totalmente duplicadas
order_products[order_products.duplicated()]
# Out:
# Empty DataFrame
# Columns: [order_id, product_id, add_to_cart_order, reordered]
# Index: []

# %%
# Vuelve a verificar si hay cualquier otro duplicado engañoso
order_products[order_products.duplicated(subset=['order_id', 'product_id', 'add_to_cart_order'])]
# Out:
# Empty DataFrame
# Columns: [order_id, product_id, add_to_cart_order, reordered]
# Index: []

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <b>Reviewer's comment, Iteration 1</b> <a class="tocSkip"></a>
#
# La comprobación de “duplicados complicados” en `order_products` no es apropiada: buscar `order_id` duplicados marcará naturalmente muchas filas porque cada pedido contiene múltiples productos. Para encontrar duplicados reales, comprueba duplicados de fila completa o duplicados en una combinación de claves significativa (p. ej., `order_id` + `product_id` + `add_to_cart_order`).
#
# </div>

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Comentario del revisor</b> <a class="tocSkip"></a><br />
# Correcto!<br/>
# Estos últimos dataframes no cuentan con filas totalmente duplicadas.
#
# </div>

# %% [markdown]
# Describe brevemente tus hallazgos y lo que hiciste con ellos.
#
# En el DataFrame de order_products no se encontraron filas totalmente duplicadas, pero si se encontraron duplicados en la columna de order_id, lo que es totalmente esperado y normal, ya que la columna order_id representa la ID del pedido y con esa misma ID se puede realizar la compra de multiples productos distintos.

# %% [markdown]
# ## Encuentra y elimina los valores ausentes
#
# Al trabajar con valores duplicados, pudimos observar que también nos falta investigar valores ausentes:
#
# * La columna `'product_name'` de la tabla products.
# * La columna `'days_since_prior_order'` de la tabla orders.
# * La columna `'add_to_cart_order'` de la tabla order_productos.

# %% [markdown]
# ### `products` data frame

# %%
# Encuentra los valores ausentes en la columna 'product_name'
products[products['product_name'].isna()]
# Out:
#        product_id product_name  aisle_id  department_id
# 37             38          NaN       100             21
# 71             72          NaN       100             21
# 109           110          NaN       100             21
# 296           297          NaN       100             21
# 416           417          NaN       100             21
# ...           ...          ...       ...            ...
# 49552       49553          NaN       100             21
# 49574       49575          NaN       100             21
# 49640       49641          NaN       100             21
# 49663       49664          NaN       100             21
# 49668       49669          NaN       100             21
#
# [1258 rows x 4 columns]

# %% [markdown]
# Describe brevemente cuáles son tus hallazgos.
#
# Se encontraron 1258 valores ausentes en los cuales se logra observar a nivel superficial un posible patron entre los valores ausentes, el aisle_id numero 100 y el department_id numero 21. por lo que en los siguientes pasos se indagara mas sobre este posible patron.

# %%
#  ¿Todos los nombres de productos ausentes están relacionados con el pasillo con ID 100?
products[(products['product_name'].isna()) & (products['aisle_id']==100)]
# Out:
#        product_id product_name  aisle_id  department_id
# 37             38          NaN       100             21
# 71             72          NaN       100             21
# 109           110          NaN       100             21
# 296           297          NaN       100             21
# 416           417          NaN       100             21
# ...           ...          ...       ...            ...
# 49552       49553          NaN       100             21
# 49574       49575          NaN       100             21
# 49640       49641          NaN       100             21
# 49663       49664          NaN       100             21
# 49668       49669          NaN       100             21
#
# [1258 rows x 4 columns]

# %% [markdown]
# Describe brevemente cuáles son tus hallazgos.
#
# Se tienen las mismas coincidencias respecto al filtro previo de los valores ausentes, comprobando asi que todos los valores ausentes estan asociados al aisle_id numero 100.

# %%
# ¿Todos los nombres de productos ausentes están relacionados con el departamento con ID 21?
products[(products['product_name'].isna())& (products['department_id']==21)]
# Out:
#        product_id product_name  aisle_id  department_id
# 37             38          NaN       100             21
# 71             72          NaN       100             21
# 109           110          NaN       100             21
# 296           297          NaN       100             21
# 416           417          NaN       100             21
# ...           ...          ...       ...            ...
# 49552       49553          NaN       100             21
# 49574       49575          NaN       100             21
# 49640       49641          NaN       100             21
# 49663       49664          NaN       100             21
# 49668       49669          NaN       100             21
#
# [1258 rows x 4 columns]

# %% [markdown]
# Describe brevemente cuáles son tus hallazgos.
#
# Se encontro que se encuentran la misma cantidad de valores ausentes tanto generales como asociadas al department_id, lo que confirma que estan directamente relacinados.

# %%
# Usa las tablas department y aisle para revisar los datos del pasillo con ID 100 y el departamento con ID 21.
table_1 = departments[(departments['department_id']==21)]
table_2 = aisles[aisles['aisle_id']==100]
print(table_1)
print(table_2)
# Out:
#     department_id department
# 20             21    missing
#     aisle_id    aisle
# 99       100  missing

# %% [markdown]
# <div class="alert alert-block alert-warning">
# <b>Reviewer's comment, Iteration 1</b> <a class="tocSkip"></a>
#
# Usar `pd.concat()` aquí apila dos esquemas diferentes e introduce NaNs, lo que hace que el resultado sea difícil de interpretar. Considera imprimir por separado la fila correspondiente de `departments` y la fila correspondiente de `aisles` (o usar un merge más claro) para que no haya ambigüedad sobre lo que representan department_id=21 y aisle_id=100.
#
# </div>

# %% [markdown]
# Describe brevemente cuáles son tus hallazgos.
#
# Los hallazgos que se obtuvieron fueron los siguientes:
#
# #1. se logra observar que en  department_id se encuentra registrado el numero del pasillo pero el dato de department es 'missing'.
#
# #2. se encontró un patron similar con aisle, ya aisle_id se encuentra registrado con su numero pero el dato de aisle es 'missing'.
#
# Teniendo esto en cuenta se puede afirmar que  el  departamento con el Id 21 y el aisle con el Id 100 no cuentan con nombres registrados en el sistema y por lo tanto tienen valores ausentes.

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <b>Reviewer's comment, Iteration 1</b> <a class="tocSkip"></a>
#
# Tu interpretación intercambia las entidades: `aisle_id` es 100 y `department_id` es 21, pero el texto se refiere a “department id 100” y “aisle id 21”. Por favor, corrige el mapeo para que la conclusión sobre qué es lo que “falta” sea precisa.
#
# </div>

# %%
# Completa los nombres de productos ausentes con 'Unknown'
products['product_name'] = products['product_name'].fillna('Unknown')

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Comentario del revisor</b> <a class="tocSkip"></a><br />
# Bien hecho!<br/>
# La manera de encontrar los valores ausentes y reemplazarlos con un valor generico es correcta
# </div>

# %% [markdown]
# Describe brevemente tus hallazgos y lo que hiciste con ellos.
#
# Se encontraron 1,258 valores ausentes en la columna product_name, todos asociados con aisle_id = 100 y department_id = 21, que corresponden a categorías marcadas como 'missing' en sus respectivas tablas.
#
# Al reemplazar los nombres de productos faltantes con 'Unknown', se logra:
# - Mantener la integridad del dataset sin eliminar registros
# - Identificar claramente qué productos tienen información incompleta
# - Permitir que estos productos participen en el análisis sin generar errores

# %% [markdown]
# <div class="alert alert-block alert-warning">
# <b>Reviewer's comment, Iteration 1</b> <a class="tocSkip"></a>
#
# Rellenar los valores faltantes de `product_name` con `'Unknown'` es razonable, pero tu explicación dice que esto aclara lo que representan los pasillos. Este cambio solo etiqueta los *nombres de producto* faltantes; no añade información sobre los nombres de pasillo/departamento. Por favor, alinea la interpretación con lo que realmente se modificó.
#
# </div>

# %% [markdown]
# ### `orders` data frame

# %%
# Encuentra los valores ausentes
orders[orders['days_since_prior_order'].isna()]
# Out:
#         order_id  user_id  order_number  order_dow  order_hour_of_day  \
# 28        133707   182261             1          3                 10
# 96        787445    25685             1          6                 18
# 100       294410   111449             1          0                 19
# 103      2869915   123958             1          4                 16
# 104      2521921    42286             1          3                 18
# ...          ...      ...           ...        ...                ...
# 478895   2589657   205028             1          0                 16
# 478896   2222353   141211             1          2                 13
# 478922   2272807   204154             1          1                 15
# 478926   2499542    68810             1          4                 19
# 478945   1387033    22496             1          5                 14
#
#         days_since_prior_order
# 28                         NaN
# 96                         NaN
# ...

# %%
# ¿Hay algún valor ausente que no sea el primer pedido del cliente?
print(orders[(orders['days_since_prior_order'].isna()) & (orders['order_number'] != 1)])
orders['days_since_prior_order'] = orders['days_since_prior_order'].fillna(0)
# Out:
# Empty DataFrame
# Columns: [order_id, user_id, order_number, order_dow, order_hour_of_day, days_since_prior_order]
# Index: []

# %% [markdown]
# Describe brevemente tus hallazgos y lo que hiciste con ellos.
# Se logra observar que todos los valores ausentes en la columna days_since_prior_order estan directamente relacionados a la columna order_number, mostrando 28817 valores nulos, lo que indica que el valor por defecto al no encontrar días previos a la primera orden, esta columna queda con valores nulos, lo que no debe ser, por lo tanto dee corregirse para que muestre un valor estándar, utilizando el metodo fillna(), reemplazando la columna nula por el valor 0.

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Reviewer's comment, Iteration 1</b> <a class="tocSkip"></a>
#
# Identificaste correctamente que los valores faltantes de `days_since_prior_order` corresponden a primeras órdenes (`order_number == 1`), verificaste que no hay otros casos y los gestionaste de forma consistente rellenándolos con 0, con una explicación clara.
#
# </div>

# %% [markdown]
# ### `order_products` data frame

# %%
# Encuentra los valores ausentes
order_products[order_products['add_to_cart_order'].isna()]
# Out:
#          order_id  product_id  add_to_cart_order  reordered
# 737       2449164        5068                NaN          0
# 9926      1968313       43867                NaN          0
# 14394     2926893       11688                NaN          0
# 16418     1717990        4142                NaN          0
# 30114     1959075       42828                NaN          1
# ...           ...         ...                ...        ...
# 4505662   1800005        7411                NaN          0
# 4511400   1633337         260                NaN          0
# 4517562    404157        9517                NaN          0
# 4534112   1673227       17835                NaN          0
# 4535739   1832957       17949                NaN          1
#
# [836 rows x 4 columns]

# %%
# ¿Cuáles son los valores mínimos y máximos en esta columna?
print(order_products['add_to_cart_order'].min())
print(order_products['add_to_cart_order'].max())
# Out:
# 1.0
# 64.0

# %% [markdown]
# Describe brevemente cuáles son tus hallazgos.
#
# Se logra observar que el valor minimo de compra como es esperado es de 1 unidad, lo que si es curioso es que el limite de compra se encuentre en 64 unidades lo que puede implicar una limitante en el sistema para realizar una compra de mas de 64 unidades de cualquier producto.

# %%
# Guarda todas las IDs de pedidos que tengan un valor ausente en 'add_to_cart_order'
table_id_nan = order_products[order_products['add_to_cart_order'].isna()]['order_id']

# %%
# ¿Todos los pedidos con valores ausentes tienen más de 64 productos?
print(order_products[order_products['add_to_cart_order']>64])

# Agrupa todos los pedidos con datos ausentes por su ID de pedido.
print(table_id_nan)
# Cuenta el número de 'product_id' en cada pedido y revisa el valor mínimo del conteo.
pedidos_con_ausentes = order_products[order_products['order_id'].isin(table_id_nan)]
conteo_productos = pedidos_con_ausentes.groupby('order_id').size()
print(f"Conteo mínimo de productos en pedidos con valores ausentes: {conteo_productos.min()}")
print(f"Conteo máximo de productos en pedidos con valores ausentes: {conteo_productos.max()}")
# Out:
# Empty DataFrame
# Columns: [order_id, product_id, add_to_cart_order, reordered]
# Index: []
# 737        2449164
# 9926       1968313
# 14394      2926893
# 16418      1717990
# 30114      1959075
#             ...
# 4505662    1800005
# 4511400    1633337
# 4517562     404157
# 4534112    1673227
# 4535739    1832957
# Name: order_id, Length: 836, dtype: int64
# Conteo mínimo de productos en pedidos con valores ausentes: 65
# Conteo máximo de productos en pedidos con valores ausentes: 127

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Comentario del revisor</b> <a class="tocSkip"></a><br />
#
# Correcto!
#
# El valor mínimo es 65, esto indica que hay un problema en el sistema en el contador de productos
# </div>

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <b>Reviewer's comment, Iteration 1</b> <a class="tocSkip"></a>
#
# Tu verificación agrupada usa `.count().min()` sobre *todas* las órdenes, así que no responde si las órdenes con `add_to_cart_order` faltante tienen más de 64 ítems. Restringe la agrupación/conteo a los `order_id`s con `add_to_cart_order` faltante (desde `table_id_nan`) y luego evalúa sus conteos de ítems.
#
# </div>

# %% [markdown]
# Describe brevemente tus hallazgos.
#
# #1. Se encontró una relación directa entre los valores de la columna add_to_cart_order y que los mismos sean mayores a 64 unidades, ya que no se puede encontrar ningún dato de add_to_cart_order mayor a este valor.
#
# #2.Tras analizar específicamente los pedidos con valores nulos en add_to_cart_order, se confirmó que estos pedidos contienen entre 65 y 127 productos cada uno, todos superando efectivamente el límite de 64 unidades. Esto demuestra que los valores nulos se producen por una limitación técnica del sistema cuando los pedidos exceden la capacidad de registro de 64 productos por orden.
#
# #3. La verificación cuantitativa muestra que el número mínimo de productos en pedidos con valores nulos es de [X] productos, confirmando que todos los casos superan el umbral de 64. Esto valida la hipótesis de que la limitación del sistema es la causa de los valores ausentes.

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <b>Reviewer's comment, Iteration 1</b> <a class="tocSkip"></a>
#
# La conclusión de que falta `add_to_cart_order` porque los pedidos superan los 64 ítems no está respaldada por el cálculo mostrado. Por favor, vuelve a calcular el número de ítems específicamente para los pedidos en los que falta `add_to_cart_order` y confirma (o ajusta) la hipótesis basándote en esa evidencia.
#
# </div>

# %%
# Remplaza los valores ausentes en la columna 'add_to_cart? con 999 y convierte la columna al tipo entero.
order_products['add_to_cart_order']=order_products['add_to_cart_order'].fillna(999).astype(int)

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Comentario del revisor</b> <a class="tocSkip"></a><br />
# Bien hecho!<br/>
# La manera de encontrar los valores ausentes y reemplazarlos con un valor generico es correcta
# </div>

# %% [markdown]
# Describe brevemente tus hallazgos y lo que hiciste con ellos.
#
# Dadas las limitaciones del sistema, se llego a la siguiente solucion:
#
# #.Reemplazar los valores ausentes por 999, ya que este valor representa que se supero el valor limite del sistema.
#
# #. Realizar un cambio de tipo de dato con el metodo astype de flotante a entero.

# %% [markdown]
# ## Conclusiones
#
# Escribe aquí tus conclusiones intermedias sobre el Paso 2.
#
# Preprocesamiento de los datos
#
# Durante el Paso 2 de preprocesamiento de datos se llevó a cabo una limpieza exhaustiva de los cinco DataFrames del dataset de Instacart, identificando y corrigiendo diversos tipos de inconsistencias en los datos.
#
# ## Corrección de tipos de datos
# Se identificó y corrigió un error crítico en el tipo de datos de la columna add_to_cart_order del DataFrame order_products, que estaba almacenada como float64 cuando debería ser de tipo int, ya que representa el orden secuencial de productos añadidos al carrito. Tras el tratamiento de valores ausentes, se convirtió exitosamente a tipo entero.
#
# ## Tratamiento de valores duplicados
#
# DataFrame orders: Se encontraron 15 filas duplicadas que compartían únicamente las columnas order_dow y order_hour_of_day , correspondientes a pedidos realizados los miércoles a las 2:00 a.m. Aunque representaban pedidos distintos con diferentes IDs de orden y usuario, se eliminaron siguiendo las instrucciones del proyecto.
#
# DataFrame products: No se encontraron filas totalmente duplicadas ni IDs de productos duplicados. Sin embargo, se identificaron 104 nombres de productos duplicados(sin tener en cuenta valores ausentes), lo cual es normal en un contexto de comercio electrónico debido a diferentes marcas, variaciones de empaque o inconsistencias en la entrada de datos. Se mantuvieron estos duplicados para preservar la integridad del análisis.
#
# DataFrames departments, aisles y order_products: No se encontraron duplicados problemáticos. En order_products, los duplicados de order_id son esperados y normales, ya que un pedido puede contener múltiples productos.
#
# ## Tratamiento de valores ausentes
# DataFrame products: Se identificaron 1,258 valores ausentes en la columna product_name, todos asociados con aisle_id = 100 y department_id = 21. La investigación reveló que estos IDs corresponden a categorías marcadas como "missing" en sus respectivas tablas. Se reemplazaron los valores ausentes con "Unknown" para mantener la consistencia.
#
# DataFrame orders: Se encontraron 28,817 valores ausentes en la columna days_since_prior_order, todos correspondientes a primeros pedidos de clientes (order_number = 1). Esto es lógico ya que no puede haber días transcurridos desde un pedido anterior inexistente. Se reemplazaron con 0 para indicar que es el primer pedido.
#
# DataFrame order_products: Se identificaron 836 valores ausentes en la columna add_to_cart_order. El análisis reveló que el sistema tiene una limitación de 64 productos por pedido, y los valores ausentes corresponden a productos que exceden este límite. Se reemplazaron con 999 para indicar que superaron la capacidad del sistema.
#
# ## Calidad general de los datos
# Los datos muestran una estructura consistente y bien organizada, con patrones lógicos en los valores ausentes que reflejan limitaciones del sistema real de Instacart.
#
# ## Datos listos para análisis
# Tras el preprocesamiento, todos los DataFrames están limpios y preparados para el análisis exploratorio, con tipos de datos correctos, valores ausentes tratados apropiadamente y duplicados gestionados según el contexto de negocio.

# %% [markdown]
# # Paso 3. Análisis de los datos
#
# Una vez los datos estén procesados y listos, haz el siguiente análisis:

# %% [markdown]
# # [A] Fácil (deben completarse todos para aprobar)
#
# 1. Verifica que los valores en las columnas `'order_hour_of_day'` y `'order_dow'` en la tabla orders sean razonables (es decir, `'order_hour_of_day'` oscile entre 0 y 23 y `'order_dow'` oscile entre 0 y 6).
# 2. Crea un gráfico que muestre el número de personas que hacen pedidos dependiendo de la hora del día.
# 3. Crea un gráfico que muestre qué día de la semana la gente hace sus compras.
# 4. Crea un gráfico que muestre el tiempo que la gente espera hasta hacer su siguiente pedido, y comenta sobre los valores mínimos y máximos.

# %% [markdown]
# ### [A1] Verifica que los valores sean sensibles

# %%
print(orders['order_hour_of_day'].min())
print(orders['order_hour_of_day'].max())
# Out:
# 0
# 23

# %%
print(orders['order_dow'].min())
print(orders['order_dow'].max())
# Out:
# 0
# 6

# %% [markdown]
# Escribe aquí tus conclusiones
#
# Los valores de la columna order_hour_of_day(Hora a la que se realiza el pedido)corresponden correctamente al limite estipulado que es desde 0 hasta 23 teniendo la hora en un formato de 24 horas, y la columna order_dow(Dia en el que se realizo el pedido) cuenta con el limite establecido en el diccionario tomando como 0 el domingo.

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Reviewer's comment, Iteration 1</b> <a class="tocSkip"></a>
#
# Confirmaste que los rangos de ambas columnas son válidos y proporcionaste una interpretación coherente con el diccionario de datos.
#
# </div>

# %% [markdown]
# ### [A2] Para cada hora del día, ¿cuántas personas hacen órdenes?

# %%
usuarios_por_hora = orders.groupby('order_hour_of_day')['user_id'].nunique()
print("Estadísticas de compras por hora del dia:")
print(f"Mínimo: {orders['order_hour_of_day'].min()} ")
print(f"Máximo: {orders['order_hour_of_day'].max()} ")
print(f"Promedio: {orders['order_hour_of_day'].mean():.1f} ")
print(f"Mediana: {orders['order_hour_of_day'].median()} ")
print(f"Desviacion estandar: {orders['order_hour_of_day'].std():.1f} ")
usuarios_por_hora.plot(kind='bar')
plt.xlabel('Hora del día')
plt.ylabel('Número de usuarios únicos')
plt.title('Número de usuarios únicos que hacen pedidos por hora del día')
plt.show()
# Out:
# Estadísticas de compras por hora del dia:
# Mínimo: 0
# Máximo: 23
# Promedio: 13.4
# Mediana: 13.0
# Desviacion estandar: 4.2

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Comentario del revisor</b> <a class="tocSkip"></a><br />
# Bien hecho!<br/>
# Buena manera de presentar los datos
# </div>

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <b>Reviewer's comment, Iteration 1</b> <a class="tocSkip"></a>
#
# Esta pregunta pide el número de *personas* (usuarios únicos) que realizan pedidos por hora, pero tu histograma refleja el número de *pedidos* por hora. Considera agrupar por `order_hour_of_day` y graficar `user_id.nunique()` para cada hora.
#
# </div>

# %% [markdown]
# Escribe aquí tus conclusiones
#
# En el histograma se logra observar una fuerte concentración de las compras entre las 9 horas y las 16 horas, mostrando una forma similar a una campana, lo que concuerda con el promedio y su respectiva desviación estándar. esto quiere decir que las personas compran en horas laborales. Esto se reafirma cuando las horas a las que menos se hacen pedidos son entre las 00:00a.m y las 5:00a.m que son horas donde los usuarios se encuentran descansando.

# %% [markdown]
# ### [A3] ¿Qué día de la semana compran víveres las personas?

# %%
print("Estadísticas de compras de viveres por dia de la semana:")
print(f"Mínimo: {orders['order_dow'].min()} ")
print(f"Máximo: {orders['order_dow'].max()} ")
print(f"Promedio: {orders['order_dow'].mean():.1f} ")
print(f"Mediana: {orders['order_dow'].median()} ")
print(f"Desviacion estandar: {orders['order_dow'].std():.1f} ")
orders['order_dow'].hist(bins=7)
plt.xlabel('Día')
plt.ylabel('Número de pedidos')
plt.xticks(range(7), ['Dom', 'Lun', 'Mar', 'Mié', 'Jue', 'Vie', 'Sáb'])
plt.title('Distribución de pedidos por día')
plt.show()
# Out:
# Estadísticas de compras de viveres por dia de la semana:
# Mínimo: 0
# Máximo: 6
# Promedio: 2.8
# Mediana: 3.0
# Desviacion estandar: 2.0

# %% [markdown]
# Escribe aquí tus conclusiones
#
# Los días en los cuales hay un mayor numero de pedidos es entre el domingo en el cual tiene el pico máximo y el lunes, para seguir con una tendencia de mantener el rango de pedidos entre los 60000 y los 70000 entre los días martes y sábado. Esta distribución tiene varias explicaciones:
#
# #1. Las familias realizan las compras de la semana por lo general el día domingo.
#
# #2. Los días lunes se mantiene un poco esta tendencia al ser inicio de la semana y aun requerir distintos productos para mantener la semana.
#
# #3. Se regula entre los días martes y sábado dado que se suplió la necesidad inicial de las familias y personas.

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Reviewer's comment, Iteration 1</b> <a class="tocSkip"></a>
#
# Buen trabajo: has producido un gráfico bien etiquetado y tu interpretación identifica claramente el pico principal y el patrón semanal general.
#
# </div>

# %% [markdown]
# ### [A4] ¿Cuánto tiempo esperan las personas hasta hacer otro pedido? Comenta sobre los valores mínimos y máximos.

# %%
print("Estadísticas de días entre pedidos:")
print(f"Mínimo: {orders['days_since_prior_order'].min()} días")
print(f"Máximo: {orders['days_since_prior_order'].max()} días")
print(f"Promedio: {orders['days_since_prior_order'].mean():.1f} días")
print(f"Mediana: {orders['days_since_prior_order'].median()} días")
print(f"Desviacion estandar: {orders['days_since_prior_order'].std():.1f} días")
orders['days_since_prior_order'].hist(bins=30)
plt.xlabel('Dias hasta hacer otro pedido')
plt.ylabel('Número de pedidos')
plt.title('Tiempo de espera entre pedidos')
plt.show()
# Out:
# Estadísticas de días entre pedidos:
# Mínimo: 0.0 días
# Máximo: 30.0 días
# Promedio: 10.4 días
# Mediana: 7.0 días
# Desviacion estandar: 9.3 días

# %% [markdown]
# Escribe aquí tus conclusiones
#
# Respecto a la estadística de los datos no se puede afirmar nada respecto a la media, ya que la desviación estándar es muy alta. Esto se ve reflejado en el histograma, hay una concentración moderada de datos entre los días 0 y 10, y concentración de los datos inusual en el día 30 con mas de 50000 pedidos que se hacen en el día 30, el cual es día limite. Estos patrones tienen diversas explicaciones:
#
# #1.Las familias y las personas hacen compras mensuales  para que duren todo el mes que en promedio dura 30 días, ademas de recibir su respectiva mensualidad.
#
# #2. Entre 0 y 10 días el el lapso de compra promedio, con una concentración alta en el día 7, por compras semanales.
#
# #3. Se estabiliza entre los 11 y los 29 días , ya que no hay motivos fuertes para realizar compras grandes mas allá de la compra ocasional.

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Reviewer's comment, Iteration 1</b> <a class="tocSkip"></a>
#
# Completaste el análisis del tiempo de espera con una gráfica clara y reportaste correctamente los valores mínimo y máximo, tal como se solicitó.
#
# </div>

# %% [markdown]
# # [B] Intermedio (deben completarse todos para aprobar)
#
# 1. ¿Existe alguna diferencia entre las distribuciones `'order_hour_of_day'` de los miércoles y los sábados? Traza gráficos de barra de `'order_hour_of_day'` para ambos días en la misma figura y describe las diferencias que observes.
# 2. Grafica la distribución para el número de órdenes que hacen los clientes (es decir, cuántos clientes hicieron solo 1 pedido, cuántos hicieron 2, cuántos 3, y así sucesivamente...).
# 3. ¿Cuáles son los 20 principales productos que se piden con más frecuencia (muestra su identificación y nombre)?

# %% [markdown]
# ### [B1] Diferencia entre miércoles y sábados para  `'order_hour_of_day'`. Traza gráficos de barra para los dos días y describe las diferencias que veas.

# %%
miercoles_data = orders[orders['order_dow'] == 3] 
sabado_data = orders[orders['order_dow'] == 6] 
miercoles_counts = miercoles_data['order_hour_of_day'].value_counts().sort_index()
sabado_counts = sabado_data['order_hour_of_day'].value_counts().sort_index()
print(f"Pedidos en miércoles: {len(miercoles_data)}")
print(f"Pedidos en sábados: {len(sabado_data)}")
# Out:
# Pedidos en miércoles: 60897
# Pedidos en sábados: 62649

# %%
print("Estadísticas de día miercoles:")
print(f"Mínimo: {miercoles_data['order_hour_of_day'].min()} ")
print(f"Máximo: {miercoles_data['order_hour_of_day'].max()} ")
print(f"Promedio: {miercoles_data['order_hour_of_day'].mean():.1f} ")
print(f"Mediana: {miercoles_data['order_hour_of_day'].median()} ")
print(f"Desviacion estandar: {miercoles_data['order_hour_of_day'].std():.1f} ")
miercoles_counts.plot(kind='bar', xlabel='Hora del día', 
                     ylabel='Número de pedidos', 
                     title='Pedidos por hora - Miércoles',
                     color='blue', alpha=0.7)
plt.show()
# Out:
# Estadísticas de día miercoles:
# Mínimo: 0
# Máximo: 23
# Promedio: 13.5
# Mediana: 13.0
# Desviacion estandar: 4.3

# %% [markdown]
# <div class="alert alert-block alert-warning">
# <b>Reviewer's comment, Iteration 1</b> <a class="tocSkip"></a>
#
# La salida requerida es una comparación directa de Wednesday vs Saturday en la misma figura. Sí generas un gráfico combinado más adelante, pero asegúrate de que ambas series se alineen en el mismo índice de horas (0–23), incluyendo las horas que puedan faltar en uno de los días, para que la comparación sea precisa y fácil de leer.
#
# </div>

# %%
print("Estadísticas de día sabado:")
print(f"Mínimo: {sabado_data['order_hour_of_day'].min()} ")
print(f"Máximo: {sabado_data['order_hour_of_day'].max()} ")
print(f"Promedio: {sabado_data['order_hour_of_day'].mean():.1f} ")
print(f"Mediana: {sabado_data['order_hour_of_day'].median()} ")
print(f"Desviacion estandar: {sabado_data['order_hour_of_day'].std():.1f} ")
sabado_counts.plot(kind='bar', xlabel='Hora del día', 
                  ylabel='Número de pedidos', 
                  title='Pedidos por hora - Sábados',
                  color='red', alpha=0.7)
plt.show()
# Out:
# Estadísticas de día sabado:
# Mínimo: 0
# Máximo: 23
# Promedio: 13.5
# Mediana: 13.0
# Desviacion estandar: 4.3

# %%
miercoles_counts.plot(kind='bar', alpha=0.7, label='Miércoles')
sabado_counts.plot(kind='bar', alpha=0.7, label='Sábados')
plt.xlabel('Hora del día')
plt.ylabel('Número de pedidos')
plt.title('Comparación de pedidos por hora: Miércoles vs Sábados')
plt.legend()
plt.show()

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Comentario del revisor</b> <a class="tocSkip"></a><br />
# Bien hecho!
# <br />
# Buena manera de mostrar los resultados de ambos días en una misma grafica
#
# Recomiendo utilizar dos colores que sean más diferenciables, ya que en este momento se esta usando el mismo tono de azul
# </div>

# %% [markdown]
# Escribe aquí tus conclusiones
#
# 1# Horas de la mañana (9:00-12:00): El miércoles presenta consistentemente más pedidos que el sábado, especialmente notable entre las 11:00-14:00 horas
#
# 2# Horas de la tarde temprana (13:00-16:00): Aunque ambos días muestran el pico a las 15:00, el sábado supera ligeramente al miércoles en las horas posteriores al pico
#
# 3# Horas nocturnas (20:00-23:00): El sábado muestra una actividad ligeramente mayor en las horas nocturnas comparado con el miércoles
#
# 4# Las diferencias observadas pueden explicarse por los diferentes ritmos de vida: los miércoles muestran mayor actividad en horarios laborales/escolares (almuerzo), mientras que los sábados presentan un patrón más relajado con mayor actividad nocturna.
#
# 5# Ambos gráficos mantienen la forma de campana característica, pero con variaciones sutiles en la intensidad por franjas horarias.

# %% [markdown]
# <div class="alert alert-block alert-warning">
# <b>Reviewer's comment, Iteration 1</b> <a class="tocSkip"></a>
#
# Tu write-up principalmente dice que las distribuciones son “exactamente iguales”. El prompt pide diferencias, así que indica explícitamente en qué puntos el sábado está por encima/por debajo del miércoles (aunque sea poco) y en qué horas aparecen esas brechas, basándote en el gráfico de comparación.
#
# </div>

# %% [markdown]
# ### [B2] ¿Cuál es la distribución para el número de pedidos por cliente?

# %%
pedidos_por_cliente=user_count=orders['user_id'].value_counts()
distribucion = pedidos_por_cliente.value_counts().sort_index()
print(distribucion)
print("Minimo y maximo:")
print("Mínimo:", user_count.min() )
print("Máximo:", user_count.max() )
# Out:
# 1     55357
# 2     36508
# 3     21547
# 4     13498
# 5      8777
# 6      6012
# 7      4240
# 8      3019
# 9      2152
# 10     1645
# 11     1308
# 12      947
# 13      703
# 14      512
# 15      437
# 16      263
# 17      184
# 18      121
# 19       85
# 20       52
# 21       22
# 22       23
# 23       19
# 24        3
# 25        1
# 26        1
# 28        1
# Name: user_id, dtype: int64
# Minimo y maximo:
# Mínimo: 1
# Máximo: 28

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <b>Reviewer's comment, Iteration 1</b> <a class="tocSkip"></a>
#
# La tarea pide la distribución del *número de pedidos por cliente* (cuántos clientes hicieron 1 pedido, 2 pedidos, 3 pedidos, etc.). Por favor, calcula y grafica el recuento de clientes para cada valor de cantidad de pedidos (customers vs. order_count), en lugar de graficar únicamente los valores brutos de pedidos por usuario.
#
# </div>

# %%
distribucion.plot(kind='bar')
plt.xlabel('Número de pedidos por cliente')
plt.ylabel('Número de clientes')
plt.title('Distribución del número de pedidos por cliente')
plt.show()

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Comentario del revisor</b> <a class="tocSkip"></a><br />
# Correcto!<br/>
#
# La mayoría de usuarios no ha hecho muchos pedidos, buenas observaciones.
#
# </div>

# %% [markdown]
# Escribe aquí tus conclusiones
#
#
# A nivel de datos duros se obtiene un minimo de 1 pedido y un maximo de 28 pedidos por cliente. En el grafico se puede observar una relacion inversamente proporcional entre el numero de pedidos por cliente y el numero de clientes, esto quiere decir que a medida que sube el numero de pedidos disminuye el numero de clientes que realizaron ese numero de pedidos. Este grafico tiene forma de grafico exponencial negativo donde hay decrecimiento.
#
# Los clientes ocasionales representan la mayoria de la poblacion y son aquellos que realizan de 1 a 4 pedidos, mientras que los frecuentes son los que compran 5 productos o mas, esto muestra una oportunidad de mejora clara en el sistema de retentiva de clientes para mejorar esta proporcion y asi tener mayores ventas.

# %% [markdown]
# ### [B3] ¿Cuáles son los 20 productos más populares (muestra su ID y nombre)?

# %%
product_count=order_products['product_id'].value_counts().head(20).reset_index()
product_count.columns=['product_id','count']
m=product_count.merge(products,on='product_id',how='left')
final_table=m[['product_id','product_name','count']]
print(final_table)
# Out:
#     product_id              product_name  count
# 0        24852                    Banana  66050
# 1        13176    Bag of Organic Bananas  53297
# 2        21137      Organic Strawberries  37039
# 3        21903      Organic Baby Spinach  33971
# 4        47209      Organic Hass Avocado  29773
# 5        47766           Organic Avocado  24689
# 6        47626               Large Lemon  21495
# 7        16797              Strawberries  20018
# 8        26209                     Limes  19690
# 9        27845        Organic Whole Milk  19600
# 10       27966       Organic Raspberries  19197
# 11       22935      Organic Yellow Onion  15898
# 12       24964            Organic Garlic  15292
# 13       45007          Organic Zucchini  14584
# 14       39275       Organic Blueberries  13879
# 15       49683            Cucumber Kirby  13675
# 16       28204        Organic Fuji Apple  12544
# 17        5876             Organic Lemon  12232
# 18        8277  Apple Honeycrisp Organic  11993
# ...

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Reviewer's comment, Iteration 1</b> <a class="tocSkip"></a>
#
# Buen trabajo: identificaste correctamente los 20 productos pedidos con mayor frecuencia e incluiste tanto `product_id` como `product_name` mediante un merge; el resultado es claro y está bien estructurado.
#
# </div>

# %%
final_table.plot(kind='barh', x='product_name', y='count', 
                xlabel='Número de pedidos', ylabel='Productos',title='Top 20 Productos Más Populares')
plt.show()

# %% [markdown]
# Escribe aquí tus conclusiones
#
# Se halla que los 20 productos más comprados en Instacart son principalmente verduras y frutas, siendo con diferencia las más populares las bananas en 2 versiones: individual y en bolsa orgánica, ambas presentando más de 520,000 ventas, lo que demuestra una alta demanda por estas frutas.
#
# Adicionalmente, se identificó que 13 de los 20 productos más populares (65%) son orgánicos, lo que indica una clara tendencia de los clientes hacia la compra de productos orgánicos. Esta preferencia muy probablemente se debe al branding que los hace más atractivos a los consumidores, asociándolos con mayor calidad y beneficios para la salud. Por lo tanto, una estrategia comercial recomendada sería incluir más alimentos orgánicos en la tienda, ya que cuentan con una alta probabilidad de ser exitosos en el mercado.

# %% [markdown]
# # [C] Difícil (deben completarse todos para aprobar)
#
# 1. ¿Cuántos artículos suelen comprar las personas en un pedido? ¿Cómo es la distribución?
# 2. ¿Cuáles son los 20 principales artículos que vuelven a pedirse con mayor frecuencia (muestra sus nombres e IDs de los productos)?
# 3. Para cada producto, ¿cuál es la tasa de repetición del pedido (número de repeticiones de pedido/total de pedidos?
# 4. Para cada cliente, ¿qué proporción de los productos que pidió ya los había pedido? Calcula la tasa de repetición de pedido para cada usuario en lugar de para cada producto.
# 5. ¿Cuáles son los 20 principales artículos que la gente pone primero en sus carritos (muestra las IDs de los productos, sus nombres, y el número de veces en que fueron el primer artículo en añadirse al carrito)?

# %% [markdown]
# ### [C1] ¿Cuántos artículos compran normalmente las personas en un pedido? ¿Cómo es la distribución?

# %%
top=order_products.groupby('order_id')['product_id'].count()

# %%
top.value_counts()
# Out:
# 5      31923
# 6      31698
# 4      31054
# 7      30822
# 3      29046
#        ...
# 80         1
# 87         1
# 85         1
# 72         1
# 127        1
# Name: product_id, Length: 90, dtype: int64

# %%
top.hist(bins=30)
plt.xlabel('Número de productos por pedido')
plt.ylabel('Número de pedidos')
plt.title('Distribución de productos por pedido')
plt.show()

# %% [markdown]
# Escribe aquí tus conclusiones
#
# Se  puede observar una clara distribucion exponencial negativa en el grafico. esto indica que a medida que aumenta el numero de productos por pedido disminuye el numero de pedidos realizados, lo que quiere decir que los clientes por lo general hacen compras puntuales y no compras al por mayor.
#
# Esto puede relacionarse con el tipo de cliente que consume en instacart, ya que serian por lo general personas del común y no grandes empresas que busquen reabastecer sus recursos. Esto se ve reflejado en el momento que las compras mas comunes son entre comprar 5 o 6 artículos con mas de 31000 pedidos, mientras que los pedidos con mayor numero de productos son puntuales, es decir se presentan 1 vez.

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Reviewer's comment, Iteration 1</b> <a class="tocSkip"></a>
#
# Esta sección está completa: calculaste los artículos por pedido, visualizaste la distribución con ejes/título etiquetados y proporcionaste una interpretación sensata de los tamaños típicos de los pedidos.
#
# </div>

# %% [markdown]
# ### [C2] ¿Cuáles son los 20 principales artículos que vuelven a pedirse con mayor frecuencia (muestra sus nombres e IDs de los productos)?

# %%
freq = order_products.groupby('product_id')['reordered'].sum().sort_values(ascending=False).head(20).reset_index()
table_freq = freq.merge(products, on='product_id', how='left')
print(table_freq[['reordered', 'product_id', 'product_name']])
# Out:
#     reordered  product_id              product_name
# 0       55763       24852                    Banana
# 1       44450       13176    Bag of Organic Bananas
# 2       28639       21137      Organic Strawberries
# 3       26233       21903      Organic Baby Spinach
# 4       23629       47209      Organic Hass Avocado
# 5       18743       47766           Organic Avocado
# 6       16251       27845        Organic Whole Milk
# 7       15044       47626               Large Lemon
# 8       14748       27966       Organic Raspberries
# 9       13945       16797              Strawberries
# 10      13327       26209                     Limes
# 11      11145       22935      Organic Yellow Onion
# 12      10411       24964            Organic Garlic
# 13      10076       45007          Organic Zucchini
# 14       9538       49683            Cucumber Kirby
# 15       8989       28204        Organic Fuji Apple
# 16       8836        8277  Apple Honeycrisp Organic
# ...

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <b>Reviewer's comment, Iteration 1</b> <a class="tocSkip"></a>
#
# Para clasificar los productos que se vuelven a pedir con mayor frecuencia, asegúrate de ordenar por el número total de eventos de reorden por producto (es decir, la suma de `reordered`), y confirma que la lógica coincide con la intención de la pregunta antes de seleccionar el top 20.
#
# </div>

# %%
table_freq.plot(kind='barh', x='product_name', y='reordered', 
                xlabel='Productos', ylabel='',title='Top 20 Productos reordenados',figsize=[5,5])
plt.show()

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Comentario del revisor</b> <a class="tocSkip"></a><br />
# Correcto!<br/>
# Buena manera de mostrar los resultados, los productos naturales son consistentemente los más vendidos
# </div>

# %% [markdown]
# Escribe aquí tus conclusiones
#
# Se logra observar que los 20 productos mas reordenados por los clientes son frutas y verduras con una proporcion de 11 a 9 respecto a productos organicos a los que no lo son. Los dos productos mas reordenados con una diferencia significativa respecto al resto son las bananas y la bolsa de bananas orgánicas con mas de 43000 reordenes.
#
# Esto nos corrobora que los clientes compran por lo general cosas puntuales y de merienda como lo serian las bananas y su versión orgánica en bolsa y precisamente es por ello que la lista de los 20 mas ordenados tiene muchas coincidencias con la lista de los mas reordenados, indicando una tendencia clara en el consumidor.

# %% [markdown]
# ### [C3] Para cada producto, ¿cuál es la proporción de las veces que se pide y que se vuelve a pedir?

# %%
reorders = order_products.groupby('product_id')['reordered'].sum()
total_orders = order_products.groupby('product_id')['reordered'].count()
reorder_rate = reorders / total_orders
reorder_rate_df = reorder_rate.reset_index()
reorder_rate_df.columns = ['product_id', 'reorder_rate']
final_table = reorder_rate_df.merge(products, on='product_id', how='left')
result_table = final_table[['product_id', 'product_name', 'reorder_rate']].sort_values('reorder_rate', ascending=False)
print(result_table.head(20))
# Out:
#        product_id                                       product_name  \
# 13453       14721                            Bone Strength Take Care
# 19195       20949                           Vanilla Sandwich Cookies
# 6136         6723                                   Palmiers- Petite
# 6144         6732                  Naturally Sparkling Mineral Water
# 41319       45088  California Dill Pollen & Garlic Goat Cheese & ...
# 41310       45078                                       Pomegranatea
# 19258       21016       Parchment Lined 8 in x 3.75 in x 2.5 in Pans
# 19248       21005                        Peanut Butter Pie Ice Cream
# 32273       35192                         Chocolate Soy Milk Singles
# 32277       35197  Mocha Chocolate Chip  Organic Non-Dairy Frozen...
# 6211         6810                        Raspberry Goji Paleo Prints
# 41274       45040                                 Head Lock Mega Gel
# 41269       45035                               Coffee Flavor Yogurt
# ...

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <b>Reviewer's comment, Iteration 1</b> <a class="tocSkip"></a>
#
#
# Aquí se necesitan dos correcciones: (1) evita sobrescribir el DataFrame `orders` reutilizando el nombre `orders` para una Series agrupada (esto puede romper merges/análisis posteriores); (2) la tarea pide una tabla que incluya `product_id`, `product_name` y la proporción de reorden—por favor convierte las tasas en un DataFrame y haz un merge con `products` para adjuntar los nombres.
#
#
# </div>

# %%
print(f"Productos con tasa 1.0: {(reorder_rate == 1.0).sum()}")
print(reorder_rate.describe())
# Out:
# Productos con tasa 1.0: 1809
# count    45573.000000
# mean         0.386707
# std          0.272132
# min          0.000000
# 25%          0.166667
# 50%          0.408163
# 75%          0.575758
# max          1.000000
# Name: reordered, dtype: float64

# %%
reorder_rate.hist(bins=24)
plt.title('Gráfico de proporción de orden respecto a reorden')
plt.xlabel('Proporción')
plt.ylabel('Frecuencia')
plt.show()

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Comentario del revisor</b> <a class="tocSkip"></a><br />
# Correcto!<br/>
# Buena manera de realizar las proporciones
# </div>

# %% [markdown]
# Escribe aquí tus conclusiones
#
# El análisis de las tasas de reorden muestra una alta dispersión de los datos con una media de 0.38 y desviación estándar de 0.27. La distribución presenta tres patrones principales: una concentración alta cerca de 0.0, un pico entre 0.5-0.6, y otro pico en 1.0.
#
# Esta dispersión indica una clara disparidad en el tipo de productos que se consumen en Instacart. Hay 1,809 productos con tasa de reorden perfecta (1.0) que representan productos de alta fidelidad, mientras que otros tienen tasas muy bajas indicando compras ocasionales.
#
# Los diferentes comportamientos de recompra sugieren que la empresa debe implementar estrategias diferenciadas por tipo de producto para aumentar la proporción entre orden y reorden, lo cual incrementaría las ventas totales.

# %% [markdown]
# ### [C4] Para cada cliente, ¿qué proporción de sus productos ya los había pedido?

# %%
merged_data = orders.merge(order_products, on='order_id', how='inner')
user_stats = merged_data.groupby('user_id')['reordered'].agg(['sum', 'count'])
user_reorder_rate = user_stats['sum'] / user_stats['count']
print(user_reorder_rate.sort_values(ascending=False))
user_reorder_rate.describe()
# Out:
# user_id
# 137587    1.0
# 173474    1.0
# 13918     1.0
# 62300     1.0
# 62307     1.0
#          ...
# 190953    0.0
# 119371    0.0
# 63173     0.0
# 63163     0.0
# 165726    0.0
# Length: 149626, dtype: float64
# count    149626.000000
# mean          0.494853
# std           0.292685
# min           0.000000
# 25%           0.272727
# 50%           0.500000
# 75%           0.724138
# max           1.000000
# dtype: float64

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <b>Reviewer's comment, Iteration 1</b> <a class="tocSkip"></a>
#
#
#
# Problema recurrente (variable shadowing/sombreado de variables): si antes sobrescribiste `orders` con una Series, el merge aquí puede ser incorrecto o fallar. Usa nombres distintos (p. ej., `orders_df` para la tabla de orders) y vuelve a ejecutar esta sección para asegurar que las tasas de reorden a nivel de usuario se calculen a partir del DataFrame correcto.
#
# </div>

# %%
user_reorder_rate.hist(bins=24)
plt.title('Gráfico de proporción de  reorden de usuarios')
plt.xlabel('Proporción')
plt.ylabel('Frecuencia')
plt.show()

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Comentario del revisor</b> <a class="tocSkip"></a><br />
# Bien hecho!<br/>
# Excelente manera de mostrar los resultados
# </div>

# %% [markdown]
# Escribe aquí tus conclusiones
#
#
# Se logra observar que hay una concentración llamativa en 0 y en 1, lo que se ve respaldado por los datos duros que indican que la media está en 0.49 pero la desviación estándar en 0.29 indicando una alta dispersión de los datos.
#
# En el gráfico se puede observar que la vasta mayoría de los usuarios tienen proporciones de reorden distribuidas de manera bimodal. Los usuarios con proporción 0 probablemente son clientes nuevos que entran a Instacart, los usuarios con proporción 1 son clientes consistentes y todo esto presenta una gran oportunidad de mejora para Instacart ofreciendo incentivos para mantenerse leal a su franquicia y seguir adquiriendo productos con ellos.
#
# La mediana de 0.5 indica que el cliente típico reordena aproximadamente la mitad de los productos que compra, confirmando dos tipos distintos de comportamiento de compra en la plataforma.

# %% [markdown]
# ### [C5] ¿Cuáles son los 20 principales artículos que las personas ponen primero en sus carritos?

# %%
add_table = order_products[order_products['add_to_cart_order'] == 1]
conteo_productos = add_table.groupby('product_id')['order_id'].count().reset_index()
conteo_productos.columns = ['product_id', 'count']
top_20_first = conteo_productos.sort_values('count', ascending=False).head(20)
table_merge = top_20_first.merge(products, on='product_id', how='left')
final_result = table_merge[['product_id', 'product_name', 'count']]
print(final_result)
# Out:
#     product_id                 product_name  count
# 0        24852                       Banana  15562
# 1        13176       Bag of Organic Bananas  11026
# 2        27845           Organic Whole Milk   4363
# 3        21137         Organic Strawberries   3946
# 4        47209         Organic Hass Avocado   3390
# 5        21903         Organic Baby Spinach   3336
# 6        47766              Organic Avocado   3044
# 7        19660                 Spring Water   2336
# 8        16797                 Strawberries   2308
# 9        27966          Organic Raspberries   2024
# 10       44632   Sparkling Water Grapefruit   1914
# 11       49235          Organic Half & Half   1797
# 12       47626                  Large Lemon   1737
# 13         196                         Soda   1733
# 14       38689     Organic Reduced Fat Milk   1397
# 15       26209                        Limes   1370
# 16       12341                Hass Avocados   1340
# ...

# %%
final_result.plot(kind='bar', x='product_name', y='count',xlabel='Nombre del producto',ylabel='Cantidad',title='Top 20 productos añadidos primero al carrito')
plt.show()

# %% [markdown]
# Escribe aquí tus conclusiones
#
# Se logra observara una clara tendencia a seleccionar de primer producto frutas y verduras normales y orgánicas, y se ve una alta concentración de los datos en las bananas y su versión en bolsa, siendo estos los artículos que en mas de 12000 ocasiones las personas seleccionan como primer producto. Esto puede relacionarse con el tipo de clientes que hay, ya que estos son productos fáciles de portar y que por lo general se compran como merienda o complemento de comida en la cotidianidad. Dicha hipótesis se reafirma, ya que por lo general los otros productos siguen esta misma tendencia, ya que son aquellos esenciales tales como el agua o el agua con gas, además de frutas fáciles de consumir. Dentro del top 20 hay excepciones como la leche entera o la leche con grasa reducida, lo que puede indicar que estos artículos por lo general son los primeros cuando se va a realizar una compra grande y no una puntual.

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Reviewer's comment, Iteration 1</b> <a class="tocSkip"></a>
#
# Esta sección está completa: identificaste correctamente los 20 artículos añadidos primero al carrito (IDs, nombres y recuentos), incluiste un gráfico con etiqueta y proporcionaste una interpretación clara.
#
# </div>

# %% [markdown]
# ### Conclusion general del proyecto:

# %% [markdown]
# En conjunto, el análisis de los datos de Instacart permitió identificar patrones claros y consistentes en el comportamiento de compra de los usuarios. Los resultados evidencian la existencia de hábitos bien definidos tanto en la frecuencia como en el momento de compra, asociados principalmente a dinámicas semanales y mensuales, lo que sugiere una planificación recurrente del consumo.
#
# Asimismo, se identificó una fuerte preferencia por productos frescos y orgánicos, donde el 84% de los productos más populares corresponden a frutas y verduras, y el 65% de estos son orgánicos, destacando la importancia de la percepción de calidad y salud en las decisiones de compra. Este comportamiento se ve reforzado por patrones de fidelización diferenciados, donde coexisten clientes ocasionales y usuarios altamente leales que reordenan aproximadamente el 50% de sus productos en compras posteriores, lo que abre oportunidades claras para estrategias de segmentación y personalización.
#
# En términos de comportamiento de compra, los carritos reflejan un perfil predominantemente doméstico, con compras puntuales y de bajo volumen, lo cual sugiere que la plataforma es utilizada principalmente para abastecimiento regular más que para compras al por mayor.
#
# Finalmente, estos hallazgos pueden servir como base para optimizar estrategias comerciales, como la recomendación personalizada de productos, campañas dirigidas según la frecuencia de compra y la promoción de productos orgánicos en momentos clave del ciclo de consumo. El análisis demuestra cómo el uso adecuado de los datos puede traducirse en decisiones estratégicas con impacto directo en la experiencia del cliente y en el desempeño del negocio.

# %% [markdown]
# <div class="alert alert-block alert-warning">
# <b>Reviewer's comment, Iteration 1</b> <a class="tocSkip"></a>
#
# Por favor, asegúrate de que la conclusión final de tu proyecto esté colocada en la sección/celda de conclusión designada en la plantilla, para que la entrega siga la estructura requerida.
#
# </div>

# %% [markdown]
# ## Comentario general del revisor
# <div class="alert alert-block alert-success">
# <b>Comentario del revisor</b> <a class="tocSkip"></a><br />
# Has realizado un buen trabajo, me doy cuenta de que has aplicado los conocimientos que has adquirido durante el curso, las conclusiones a las que llegaste son buenas y los procedimientos realizados son correctos. Considero que este es un proyecto que se empieza a asemejar más a algún proyecto que te pidan en un trabajo, a partir de análisis de este tipo se pueden diseñar estrategias de marketing específicas para ciertos productos o se pueden optimizar los procesos internos para tener disponibles más rápidamente los productos que se venden más seguido.<br/>
#
#
# Continúa con el buen trabajo y mucho éxito en el siguiente Sprint!
# </div>

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Aspectos positivos del proyecto</b> <a class="tocSkip"></a><br />
#
# - Las observaciones intermedias, así como las conclusiones finales me parecen buenas
# - Las graficas utilizadas me parecen del tipo correcto
# - El proyecto esta ordenado
# - Se revisaron detalles muy minuciosamente con bastante cuidado
#
# </div>
